# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
train = pd.read_csv('train.csv') # option: nrows=10000

# %%
test = pd.read_csv('test.csv') # option: nrows=10000

# %%
test_key = test['txkey']

# %%
train['txkey'].value_counts()
# Out:
# 2047       1
# 462260     1
# 517545     1
# 523690     1
# 521643     1
# 511404     1
# 509357     1
# 515502     1
# 513455     1
# 470448     1
# 468401     1
# 460213     1
# 458122     1
# 466358     1
# 464311     1
# 486840     1
# 484793     1
# 490938     1
# 488891     1
# 478652     1
# 482750     1
# 480703     1
# 519592     1
# 497063     1
# 499110     1
# 492965     1
# 449934     1
# 404880     1
# 402833     1
# 408978     1
#           ..
# 1762806    1
# 1764855    1
# 1742328    1
# 1744377    1
# 1738234    1
# 1740283    1
# 1734116    1
# 1721826    1
# 1801669    1
# 1727969    1
# 1795526    1
# 1797575    1
# 1775048    1
# 1777097    1
# 1770954    1
# 1773003    1
# 1783244    1
# 1785293    1
# 1779150    1
# 1781199    1
# 1834453    1
# 1807832    1
# 1809881    1
# 1803738    1
# 1805787    1
# 1816028    1
# 1811934    1
# 1813983    1
# 1725920    1
# 0          1
# Name: txkey, Length: 1521787, dtype: int64

# %%
train['conam'] = train['conam'].astype(float)
train['iterm'] = train['iterm'].astype(float)

# %%
train['acqic'] = train['acqic'].astype(str)
train['bacno'] = train['bacno'].astype(str)
train['cano'] = train['cano'].astype(str)
train['contp'] = train['contp'].astype(str)
train['csmcu'] = train['csmcu'].astype(str)
train['ecfg'] = train['ecfg'].astype(str)
train['insfg'] = train['insfg'].astype(str)
train['etymd'] = train['etymd'].astype(str)
train['flbmk'] = train['flbmk'].astype(str)
train['flg_3dsmk'] = train['flg_3dsmk'].astype(str)
train['hcefg'] = train['hcefg'].astype(str)
train['mcc'] = train['mcc'].astype(str)
train['mchno'] = train['mchno'].astype(str)
train['ovrlt'] = train['ovrlt'].astype(str)
train['scity'] = train['scity'].astype(str)
train['stocn'] = train['stocn'].astype(str)
train['stscd'] = train['stscd'].astype(str)

# %%
test['conam'] = test['conam'].astype(float)
test['iterm'] = test['iterm'].astype(float)

# %%
test['acqic'] = test['acqic'].astype(str)
test['bacno'] = test['bacno'].astype(str)
test['cano'] = test['cano'].astype(str)
test['contp'] = test['contp'].astype(str)
test['csmcu'] = test['csmcu'].astype(str)
test['ecfg'] = test['ecfg'].astype(str)
test['insfg'] = test['insfg'].astype(str)
test['etymd'] = test['etymd'].astype(str)
test['flbmk'] = test['flbmk'].astype(str)
test['flg_3dsmk'] = test['flg_3dsmk'].astype(str)
test['hcefg'] = test['hcefg'].astype(str)
test['mcc'] = test['mcc'].astype(str)
test['mchno'] = test['mchno'].astype(str)
test['ovrlt'] = test['ovrlt'].astype(str)
test['scity'] = test['scity'].astype(str)
test['stocn'] = test['stocn'].astype(str)
test['stscd'] = test['stscd'].astype(str)

# %% [markdown]
# # missing values

# %%
train.loc[train['flbmk'] =='nan','flbmk'] = 'N'

# %%
train.loc[train['flg_3dsmk'] =='nan','flg_3dsmk'] = 'N'

# %%
test['flbmk'].fillna('N', inplace=True)
test['flg_3dsmk'].fillna('N', inplace=True)

# %% [markdown]
# # 該卡在三個月的交易次數 transaction_count

# %%
train_with_cano_only = train[['cano']]

# %%
cano_group = train_with_cano_only.groupby('cano')

# %%
transaction_count_dict = {}
ith_cano_group = 0
for i in cano_group.groups.keys():
    ith_cano_group += 1
    s = cano_group.get_group(i)
    trans =  len(s)
    
    transaction_count_dict.update( { "{}".format(i) : trans } )
    
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
train['transaction_count'] = 0
for index, row in train.iterrows():
    train.at[index, 'transaction_count'] = transaction_count_dict.get(row['cano']) # checked logic
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
train
# Out:
#         acqic   bacno    cano    conam contp csmcu ecfg etymd flbmk flg_3dsmk  \
# 0        6881  113261   38038   513.80     5     0    N     0     N         N
# 1           0  134508   45725   465.62     5     0    N     2     N         N
# 2        6881   15408  188328   513.80     5     0    N     0     N         N
# 3        6716  157159   29967  1016.11     5    62    N     5     N         N
# 4        5975  105985   81305   713.66     5    62    N     4     N         N
# 5           0   78377    2295   465.62     5     0    N     2     N         N
# 6        6411   94435   49219  1806.49     3    62    N     4     N         N
# 7        6769  112032  177989   526.88     6    62    N     2     N         N
# 8        6092   92294   85535   201.39     2    62    N     2     N         N
# 9           0   16279  110755   465.62     5     0    N     2     N         N
# 10       6882   49387   57083     0.00     5     0    N     0     N         N
# ...

# %%
# combination with train and test to make the overall test to include train counts
train_test_concat = pd.concat([train, test], ignore_index=True)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
# train[train['cano']=='77226'] to make sure tranaction count is right

# %%
#test[test['cano']=='77226'] to make sure tranaction count is right

# %%
test_with_cano = train_test_concat[['cano']]
cano_group = test_with_cano.groupby('cano')

transaction_count_dict = {}
ith_cano_group = 0
for i in cano_group.groups.keys():
    ith_cano_group += 1
    s = cano_group.get_group(i)
    trans =  len(s)
    
    transaction_count_dict.update( { "{}".format(i) : trans } )
    
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
test['transaction_count'] = 0
for index, row in test.iterrows():
    test.at[index, 'transaction_count'] = transaction_count_dict.get(row['cano']) # checked logic
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000

# %%
test
# Out:
#        acqic   bacno    cano    conam contp csmcu ecfg etymd flbmk flg_3dsmk  \
# 0       6881  163188  116799   513.80     5     0    N     0     N         N
# 1       6881  163188  116799   513.80     5     0    N     0     N         N
# 2       6881  163188  116799   513.80     5     0    N     0     N         N
# 3       6881  163188  116799   513.80     5     0    N     0     N         N
# 4       6881  163188  116799   513.80     5     0    N     0     N         N
# 5       6881  163188  116799   513.80     5     0    N     0     N         N
# 6       6881  163188  116799   513.80     5     0    N     0     N         N
# 7       6881  163188  116799   513.80     5     0    N     0     N         N
# 8       6881  163188  116799   513.80     5     0    N     0     N         N
# 9       6881  163188  116799   513.80     5     0    N     0     N         N
# 10      6881  163188  116799   513.80     5     0    N     0     N         N
# ...

# %%
#回來看 test之transaction count有無包含train的count

# %% [markdown]
# 每一筆交易金額減掉該卡三個月消費金額的平均 ( 標準化? 但原本資料已經過變化)

# %%
train_with_cano_amount = train[['cano','conam']]

# %%
cano_amount_group = train_with_cano_amount.groupby('cano')

# %%
# for i in cano_amount_group.groups.keys():
# #     ith_cano_group += 1
#     s = cano_amount_group.get_group(i)
#     amount_sum = s.sum()['conam']
#     print(amount_sum)

# %%
avg_amount = {}
ith_cano_group = 0
for i in cano_amount_group.groups.keys():
    ith_cano_group += 1
    s = cano_amount_group.get_group(i)
    amount_sum = s.sum()['conam'] / len(s)
    
    avg_amount.update( { "{}".format(i) : amount_sum } )
    
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
train['conam_minus_avg'] = 0.5 # make sure this column is in decimal,god damnit make me debugging so long
for index, row in train.iterrows():
    avg = avg_amount.get(row['cano']) # checked logic
    train.at[index, 'conam_minus_avg'] = train['conam'][index] - avg # checked logic
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
test_with_cano_amount = test[['cano','conam']]
test_cano_amount_group = test_with_cano_amount.groupby('cano')

# %%
avg_amount = {}
ith_cano_group = 0
for i in test_cano_amount_group.groups.keys():
    ith_cano_group += 1
    s = test_cano_amount_group.get_group(i)
    amount_sum = s.sum()['conam'] / len(s)
    
    avg_amount.update( { "{}".format(i) : amount_sum } )
    
    if(ith_cano_group%10000==0):
        print(ith_cano_group)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000

# %%
test['conam_minus_avg'] = 0.5 # make sure this column is in decimal,god damnit make me debugging so long
for index, row in test.iterrows():
    avg = avg_amount.get(row['cano']) # checked logic
    test.at[index, 'conam_minus_avg'] = test['conam'][index] - avg # checked logic
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000

# %% [markdown]
# 消費地國別變動激烈程度 (三個月) :   消費地國別次數/該卡號消費次數
# 這邊做的假設是，前三個月的消費地國別已經代表此人常消費的國別

# %%
train_with_cano_stocn = train[['cano','stocn']]

# %%
cano_stocn_group = train_with_cano_stocn.groupby('cano')

stocn_count_dic = {}
ith_cano_group = 0
for i in cano_stocn_group.groups.keys():
    ith_cano_group += 1
    s = cano_stocn_group.get_group(i)
    stocn_count = s['stocn'].value_counts()
    stocn_prop_dict = {}
    for n,v in stocn_count.iteritems():
        stocn_prop_dict.update({n : v / len(s)})

    stocn_count_dic.update( { "{}".format(i) : stocn_prop_dict } )
    
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
train['stocn_cano_proportion'] = 0.5 # need to be float
for index, row in train.iterrows():
    train.at[index,'stocn_cano_proportion'] = stocn_count_dic[row['cano']].get(row['stocn'])
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
# combination with train and test to make the overall test to include train proportions
train_test_concat = pd.concat([train, test], ignore_index=True)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#do same thing with test set again
test_with_cano_stocn = train_test_concat[['cano','stocn']]

# %%
cano_stocn_group  = test_with_cano_stocn.groupby('cano')


stocn_count_dic = {}

ith_cano_group = 0
for i in cano_stocn_group.groups.keys():
    ith_cano_group += 1
    s = cano_stocn_group.get_group(i)
    stocn_count = s['stocn'].value_counts()
    stocn_prop_dict = {}
    for n,v in stocn_count.iteritems():
        stocn_prop_dict.update({n : v / len(s)})

    stocn_count_dic.update( { "{}".format(i) : stocn_prop_dict } )
    
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
test['stocn_cano_proportion'] = 0.5 # need to be float
for index, row in test.iterrows():
    test.at[index,'stocn_cano_proportion'] = stocn_count_dic[row['cano']].get(row['stocn'])
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000

# %% [markdown]
# mcc scity proportion feature

# %%
train_with_cano_mcc_city = train[['cano','mcc','scity']]

# %%
cano_mcc_scity_group = train_with_cano_mcc_city.groupby('cano')

mcc_count_dic = {}
scity_count_dic = {}
ith_cano_group = 0

#checked logic
for i in cano_mcc_scity_group.groups.keys():
    ith_cano_group += 1
    s = cano_mcc_scity_group.get_group(i)
    mcc_count = s['mcc'].value_counts()
    scity_count = s['scity'].value_counts()
    mcc_prop_dict = {}
    scity_prop_dict = {}
    for n,v in mcc_count.iteritems():
        mcc_prop_dict.update({n : v / len(s)})
    for n,v in scity_count.iteritems():
        scity_prop_dict.update({n : v / len(s)})
        
        
    mcc_count_dic.update( { "{}".format(i) : mcc_prop_dict } )
    scity_count_dic.update( { "{}".format(i) : scity_prop_dict } )
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
train['mcc_cano_proportion'] = 0.5 # need to be float
train['scity_cano_proportion'] = 0.5 # need to be float
for index, row in train.iterrows():
    train.at[index,'mcc_cano_proportion'] = mcc_count_dic[row['cano']].get(row['mcc'])
    train.at[index,'scity_cano_proportion'] = scity_count_dic[row['cano']].get(row['scity'])
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
# combination with train and test to make the overall test to include train proportions
train_test_concat = pd.concat([train, test], ignore_index=True)
#do same thing with test set again
test_with_cano_mcc_city = train_test_concat[['cano','mcc','scity']]
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
cano_mcc_scity_group = test_with_cano_mcc_city.groupby('cano')

mcc_count_dic = {}
scity_count_dic = {}
ith_cano_group = 0

#checked logic
for i in cano_mcc_scity_group.groups.keys():
    ith_cano_group += 1
    s = cano_mcc_scity_group.get_group(i)
    mcc_count = s['mcc'].value_counts()
    scity_count = s['scity'].value_counts()
    mcc_prop_dict = {}
    scity_prop_dict = {}
    for n,v in mcc_count.iteritems():
        mcc_prop_dict.update({n : v / len(s)})
    for n,v in scity_count.iteritems():
        scity_prop_dict.update({n : v / len(s)})
        
        
    mcc_count_dic.update( { "{}".format(i) : mcc_prop_dict } )
    scity_count_dic.update( { "{}".format(i) : scity_prop_dict } )
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
test['mcc_cano_proportion'] = 0.5 # need to be float
test['scity_cano_proportion'] = 0.5 # need to be float
for index, row in test.iterrows():
    test.at[index,'mcc_cano_proportion'] = mcc_count_dic[row['cano']].get(row['mcc'])
    test.at[index,'scity_cano_proportion'] = scity_count_dic[row['cano']].get(row['scity'])
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000

# %% [markdown]
# train[train['cano']=='138672']

# %% [markdown]
# train[train['cano']=='138672']['mcc'].value_counts()['289']

# %% [markdown]
# test[test['cano']=='138672']['mcc'].value_counts()['289']

# %% [markdown]
# test[test['cano']=='138672']

# %%
# (23 + 9 ) / 117 = 0.2735042735   ==  mcc[289]之 mcc proportion

# %% [markdown]
# # 每個cano group 裡 資料內的similiarty
# # similarity feature
# # Unfinished

# %%
def jaccard_similarity(list1, list2):
    intersection = len(list(set(list1).intersection(set(list2))))
    union = (len(set(list1)) + len(set(list2))) - intersection
    return float(intersection) / union

# %% [markdown]
# # feature : group by cano, locdt 出現的次數 / 總交易次數

# %%
train_with_cano_locdt = train[['cano','locdt']]

# %%
cano_locdt_group = train_with_cano_locdt.groupby('cano')

# %%
locdt_count_dic = {}
ith_cano_group = 0
for i in cano_locdt_group.groups.keys():
    ith_cano_group += 1
    s = cano_locdt_group.get_group(i)
    locdt_count = s['locdt'].value_counts()
    locdt_prop_dict = {}
    for n,v in locdt_count.iteritems():
        locdt_prop_dict.update({n : v / len(s)})

    locdt_count_dic.update( { "{}".format(i) : locdt_prop_dict } )
    
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
train['locdt_cano_proportion'] = 0.5 # need to be float
for index, row in train.iterrows():
    train.at[index,'locdt_cano_proportion'] = locdt_count_dic[row['cano']].get(row['locdt'])
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
# combination with train and test to make the overall test to include train proportions
train_test_concat = pd.concat([train, test], ignore_index=True)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#do same thing with test set again
test_with_cano_locdt = train_test_concat[['cano','locdt']]

# %%
cano_locdt_group  = test_with_cano_locdt.groupby('cano')


locdt_count_dic = {}

ith_cano_group = 0
for i in cano_locdt_group.groups.keys():
    ith_cano_group += 1
    s = cano_locdt_group.get_group(i)
    locdt_count = s['locdt'].value_counts()
    locdt_prop_dict = {}
    for n,v in locdt_count.iteritems():
        locdt_prop_dict.update({n : v / len(s)})

    locdt_count_dic.update( { "{}".format(i) : locdt_prop_dict } )
    
    if(ith_cano_group%1000==0):
        print(ith_cano_group)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
test['locdt_cano_proportion'] = 0.5 # need to be float
for index, row in test.iterrows():
    test.at[index,'locdt_cano_proportion'] = stocn_count_dic[row['cano']].get(row['locdt'])
    if(index%10000 == 0):
        print(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000

# %% [markdown]
# # 該人該國平均花費金額？
# group by cano
# group by stocn
# conam / len(stocn.value_counts())

# %% [markdown]
# # 想辦法融合locdt跟loctm
# 然後計算此次交易與上一次交易的時間差距

# %%
train.to_csv('train_feature.csv',index=False)

# %%
test.to_csv('test_feature.csv',index=False)
